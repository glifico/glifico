# %%
import requests as req

# %%
data = {'user':'admin', 'token':'glifico'}
headers = {"Content-type": "application/x-www-form-urlencoded"}

# %%
r = req.post('http://test.glifico.com/runtime.php', json = data, headers=headers)
r.status_code
# Out:
# 200

# %%
out = r.json()
out
# Out:
# [{'job': 60,
#   'object': {'id': 60,
#    'job': 'Trial Job 3',
#    'price': '6240',
#    'currency': 'EUR - EURO',
#    'status': 'Assigned',
#    'description': 'Trial job to test job assignement 3',
#    'username': 'agenzia',
#    'translated': None,
#    'translator': 'traduttore',
#    'secondtranslator': 'Claudia',
#    'document': 'https://cdn.filestackcontent.com/R7abSvaETrak3W3hH0AK',
#    'preview': None,
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-16',
#    'ncharacters': 12000,
#    'languagefrom': 'Spanish',
#    'secondprice': '1320',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 1,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 61,
#   'object': {'id': 61,
#    'job': 'Trial job - test phase',
#    'price': '92',
#    'currency': 'EUR - EURO',
#    'status': 'To Be Assigned',
#    'description': 'Trial job to test search - 17/08/2018',
#    'username': 'agenzia',
#    'translated': None,
#    'translator': 'test1',
#    'secondtranslator': 'test10',
#    'document': 'https://cdn.filestackcontent.com/vrVAUz6OQ8egv3UCDaQn',
#    'preview': None,
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-18',
#    'ncharacters': 1,
#    'languagefrom': 'English',
#    'secondprice': '96',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 62,
#   'object': {'id': 62,
#    'job': 'Job trial',
#    'price': '920',
#    'currency': 'EUR - EURO',
#    'status': 'To Be Assigned',
#    'description': 'Tria 17/08/18',
#    'username': 'agenzia',
#    'translated': None,
#    'translator': 'test1',
#    'secondtranslator': 'test7',
#    'document': 'https://cdn.filestackcontent.com/sA51E4BGSFCHFBwDw52u',
#    'preview': None,
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-18',
#    'ncharacters': 10,
#    'languagefrom': 'English',
#    'secondprice': '960',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 18,
#   'object': {'id': 18,
#    'job': 'Userguide job',
#    'price': '4.56',
#    'currency': 'EUR - EURO',
#    'status': 'Assigned',
#    'description': 'A guided job to translate',
#    'username': 'agenzia',
#    'translated': 'https://cdn.filestackcontent.com/9BQp9w0QTxWP3fNISKBD',
#    'translator': 'test',
#    'secondtranslator': 'luca',
#    'document': 'https://cdn.filestackcontent.com/MoTytfNWREaJkuqic9Mq',
#    'preview': 'https://cdn.filestackcontent.com/2ySvL8uuRe6sYXVEBxOW',
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2042-12-31',
#    'ncharacters': 1000,
#    'languagefrom': 'English',
#    'secondprice': '1',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 1,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 74,
#   'object': {'id': 74,
#    'job': 'test date',
#    'price': '540',
#    'currency': 'EUR - EURO',
#    'status': 'To Be Assigned',
#    'description': 'rrevwvrtv',
#    'username': 'agenzia',
#    'translated': None,
#    'translator': 'simona',
#    'secondtranslator': None,
#    'document': 'https://cdn.filestackcontent.com/Dgflyi2SC2hcPk4859RJ',
#    'preview': None,
#    'secondstatus': None,
#    'deadline': '2018-08-18',
#    'ncharacters': 10,
#    'languagefrom': 'English',
#    'secondprice': None,
#    'secondcurrency': None,
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 57,
#   'object': {'id': 57,
#    'job': 'Contratto ABB',
#    'price': '9200',
#    'currency': 'EUR - EURO',
#    'status': 'To Be Assigned',
#    'description': 'Legal translation for a big company',
#    'username': 'GioAgenzia',
#    'translated': 'https://cdn.filestackcontent.com/NQEAXlKRQUOv15n8gLei',
#    'translator': 'luca',
#    'secondtranslator': 'test',
#    'document': 'https://cdn.filestackcontent.com/Pdvr3gcjR5QGWylXYIfQ',
#    'preview': 'https://cdn.filestackcontent.com/3fVUdWTuC50Xh96v6W5w',
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-01',
#    'ncharacters': 100,
#    'languagefrom': 'English',
#    'secondprice': '1',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 59,
#   'object': {'id': 59,
#    'job': 'tRIAL jOB 2',
#    'price': '6240',
#    'currency': 'EUR - EURO',
#    'status': 'Refused',
#    'description': 'Trial jon to test job assignement 2',
#    'username': 'agenzia',
#    'translated': None,
#    'translator': 'traduttore',
#    'secondtranslator': 'giuliapiaser',
#    'document': 'https://cdn.filestackcontent.com/9HQazNzPR0I94ATNSEyR',
#    'preview': None,
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-16',
#    'ncharacters': 12000,
#    'languagefrom': 'Spanish',
#    'secondprice': '1320',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 15,
#   'object': {'id': 15,
#    'job': 'engl->ital',
#    'price': '4.56',
#    'currency': 'EUR - EURO',
#    'status': 'Accepted',
#    'description': 'pagato da filippo',
#    'username': 'agenzia',
#    'translated': 'https://cdn.filestackcontent.com/TYrGb9QlS0KuavfQ2sDt',
#    'translator': 'luca',
#    'secondtranslator': 'test',
#    'document': 'https://cdn.filestackcontent.com/kYFKpaOHS3mVGoMCk4lv',
#    'preview': 'https://cdn.filestackcontent.com/VV0V49ZARKSYUIhIq5bw',
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-01',
#    'ncharacters': 1000,
#    'languagefrom': 'English',
#    'secondprice': '1',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 17,
#   'object': {'id': 17,
#    'job': 'prova aajbhj',
#    'price': '4.56',
#    'currency': 'EUR - EURO',
#    'status': 'Paid',
#    'description': 'prova prova',
#    'username': 'agenzia',
#    'translated': 'https://cdn.filestackcontent.com/xGIx1mCvTMiF5fTf0spY',
#    'translator': 'luca',
#    'secondtranslator': 'test',
#    'document': 'https://cdn.filestackcontent.com/S5TtYIMaSPy1SeiuHbMk',
#    'preview': 'https://cdn.filestackcontent.com/cez6lOFYTE6VScY2RhLg',
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-01',
#    'ncharacters': 1000,
#    'languagefrom': 'English',
#    'secondprice': '1',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 1,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 66,
#   'object': {'id': 66,
#    'job': 'fdsdfsd',
#    'price': '5400',
#    'currency': 'EUR - EURO',
#    'status': 'To Be Assigned',
#    'description': 'sdff',
#    'username': 'agenzia',
#    'translated': None,
#    'translator': 'simona',
#    'secondtranslator': 'VL11939',
#    'document': 'https://cdn.filestackcontent.com/2LBoS9KLRG6YF5uKOGjf',
#    'preview': None,
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-18',
#    'ncharacters': 100,
#    'languagefrom': 'English',
#    'secondprice': '5400',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 0,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'Italian',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801},
#  {'job': 55,
#   'object': {'id': 55,
#    'job': 'awesome job',
#    'price': '4.56',
#    'currency': 'EUR - EURO',
#    'status': 'Paid',
#    'description': 'aa',
#    'username': 'agenzia',
#    'translated': 'https://cdn.filestackcontent.com/sWi2Mb75RGWMhAJKQAD8',
#    'translator': 'test',
#    'secondtranslator': 'luca',
#    'document': 'https://cdn.filestackcontent.com/iknEvaGQ3yHKLilB9HZy',
#    'preview': 'https://cdn.filestackcontent.com/mS7eB5TPR9inOrcf3ZFE',
#    'secondstatus': 'To Be Assigned',
#    'deadline': '2018-08-01',
#    'ncharacters': 12,
#    'languagefrom': 'Italian',
#    'secondprice': '1',
#    'secondcurrency': 'EUR - EURO',
#    'whoaccepted': 1,
#    'createdline': '2018-08-17 17:42:11',
#    'languageto': 'English',
#    'urgency': 'yes'},
#   'interval': {'y': 0,
#    'm': 0,
#    'd': 1,
#    'h': 22,
#    'i': 41,
#    's': 21,
#    'f': 0,
#    'weekday': 0,
#    'weekday_behavior': 0,
#    'first_last_day_of': 0,
#    'invert': 0,
#    'days': 1,
#    'special_type': 0,
#    'special_amount': 0,
#    'have_weekday_relative': 0,
#    'have_special_relative': 0},
#   'createdsince': 2801}]

# %%
out['statuscode']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-61ce30b8f5a4> in <module>()
# ----> 1 out['statuscode']
#
# TypeError: list indices must be integers or slices, not str

# %%
# Out:
# 200
