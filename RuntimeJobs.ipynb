# %%
import requests as req
import pandas as pd
from time import sleep

# %%
data = {'user':'admin', 'token':'glifico'}
headers = {"Content-type": "application/x-www-form-urlencoded"}

# %%
r = req.post('http://test.glifico.com/runtime.php', json = data, headers=headers)
r.status_code
# Out:
# 200

# %%
out = r.json()
#out

# %%
pd.DataFrame(data=out)
# Out:
#     choice  createdsince           first  \
# 0        0             5         Refused
# 1        2            98         Refused
# 2        0           458  To Be Assigned
# 3        0          2888  To Be Assigned
# 4        0          2888  To Be Assigned
# 5        0          2888  To Be Assigned
# 6        0          2888  To Be Assigned
# 7        0          2888  To Be Assigned
# 8        0          2888        Accepted
# 9        0          2888  To Be Assigned
# 10       1          2888        Assigned
#
#                                              interval  job  \
# 0   {'y': 0, 'm': 0, 'd': 0, 'h': 0, 'i': 5, 's': ...   66
# 1   {'y': 0, 'm': 0, 'd': 0, 'h': 1, 'i': 38, 's':...   18
# 2   {'y': 0, 'm': 0, 'd': 0, 'h': 7, 'i': 38, 's':...   55
# 3   {'y': 0, 'm': 0, 'd': 2, 'h': 0, 'i': 8, 's': ...   60
# 4   {'y': 0, 'm': 0, 'd': 2, 'h': 0, 'i': 8, 's': ...   59
# 5   {'y': 0, 'm': 0, 'd': 2, 'h': 0, 'i': 8, 's': ...   15
# ...

# %%
while(True):
    r = req.post('http://test.glifico.com/runtime.php', json = data, headers=headers)
    print(r.status_code)
    sleep(1)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...
